# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install -r '/content/drive/MyDrive/requirements.txt'

# %% [markdown]
# ### 2nd
# - f1-score: 0.5232

# %%
from ultralytics import YOLO

model = YOLO('yolov8s.pt')  # YOLOv8n → YOLOv8s (성능 우선)

model.train(
    data='/content/drive/MyDrive/USC-Hackathon/project/data.yaml',
    epochs=100,                    # 더 많은 학습
    imgsz=896,                     # 해상도 증가
    batch=16,
    project='/content/drive/MyDrive/USC-Hackathon/project',
    name='rdm_v8s_100ep_aug_highres_clswt',
    pretrained=True,
    save=True,
    augment=True,
    auto_augment='randaugment',   # 다양한 증강 적용
    box=7.0,
    cls=0.5,
    dfl=1.0,
    cache=True,
    patience=20,
    amp=True
)
