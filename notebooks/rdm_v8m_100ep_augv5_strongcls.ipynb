# %%
from google.colab import drive
from IPython.display import clear_output
drive.mount('/content/drive')
# !pip install -r '/content/drive/MyDrive/requirements.txt'
clear_output()

# %% [markdown]
# ### v5
# - f1-score

# %%
from ultralytics import YOLO

# 모델 선택 (YOLOv8m: 더 깊은 백본)
model = YOLO('yolov8m.pt')

model.train(
    data='/content/drive/MyDrive/USC-Hackathon/project/data.yaml',
    epochs=100,
    imgsz=1024,
    batch=16,
    project='/content/drive/MyDrive/USC-Hackathon/project',
    name='rdm_v8m_100ep_augv5_strongcls',
    pretrained=True,
    save=True,

    # 손실 가중치
    box=6.0,
    cls=2.0,
    dfl=1.5,

    # 증강 전략
    augment=True,
    auto_augment='randaugment',
    mosaic=1.0,
    mixup=0.4,
    copy_paste=0.4,
    hsv_h=0.05,
    hsv_v=0.1,

    # 학습 안정화
    cache=True,
    amp=True,
    patience=20
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8m.pt to 'yolov8m.pt'...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 94.0MB/s]
# New https://pypi.org/project/ultralytics/8.3.169 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.168 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=True, auto_augment=randaugment, batch=16, bgr=0.0, box=6.0, cache=True, cfg=None, classes=None, close_mosaic=10, cls=2.0, conf=None, copy_paste=0.4, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/USC-Hackathon/project/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.05, hsv_s=0.7, hsv_v=0.1, imgsz=1024, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.4, mode=train, model=yolov8m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=rdm_v8m_100ep_augv5_strongcls2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/USC-Hackathon/project, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/USC-Hackathon/project/rdm_v8m_100ep_augv5_strongcls2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 38.6MB/s]
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3778012  ultralytics.nn.modules.head.Detect           [4, [192, 384, 576]]
# Model summary: 169 layers, 25,858,636 parameters, 25,858,620 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 128MB/s]
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.5±0.2 ms, read: 0.1±0.0 MB/s, size: 68.6 KB)
# train: Scanning /content/drive/MyDrive/USC-Hackathon/project/labels/train.cache... 5436 images, 0 backgrounds, 0 corrupt: 100%|██████████| 5436/5436 [00:00<?, ?it/s]
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (15.9GB RAM): 100%|██████████| 5436/5436 [01:42<00:00, 52.79it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.5±0.1 ms, read: 0.1±0.0 MB/s, size: 75.2 KB)
# val: Scanning /content/drive/MyDrive/USC-Hackathon/project/labels/val.cache... 603 images, 0 backgrounds, 0 corrupt: 100%|██████████| 603/603 [00:00<?, ?it/s]
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (1.8GB RAM): 100%|██████████| 603/603 [00:02<00:00, 279.43it/s]
# Plotting labels to /content/drive/MyDrive/USC-Hackathon/project/rdm_v8m_100ep_augv5_strongcls2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Image sizes 1024 train, 1024 val
# Using 8 dataloader workers
# Logging results to /content/drive/MyDrive/USC-Hackathon/project/rdm_v8m_100ep_augv5_strongcls2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      14.2G      1.846      13.85      2.309         81       1024: 100%|██████████| 340/340 [07:10<00:00,  1.27s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:18<00:00,  1.01it/s]
#                    all        603       1646      0.279      0.258       0.18     0.0626
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      14.4G      1.789      11.87      2.278         76       1024: 100%|██████████| 340/340 [07:08<00:00,  1.26s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:18<00:00,  1.03it/s]
#                    all        603       1646      0.151       0.23     0.0809     0.0292
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      14.4G       1.76      11.73      2.275         61       1024: 100%|██████████| 340/340 [07:07<00:00,  1.26s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:18<00:00,  1.04it/s]
#                    all        603       1646      0.333       0.27      0.219     0.0766
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      14.4G      1.725      11.32      2.224         55       1024: 100%|██████████| 340/340 [07:06<00:00,  1.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:18<00:00,  1.05it/s]
#                    all        603       1646      0.291      0.308      0.226     0.0861
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      14.4G      1.676       10.9      2.168         89       1024: 100%|██████████| 340/340 [07:05<00:00,  1.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:18<00:00,  1.05it/s]
#                    all        603       1646      0.381      0.345      0.305      0.123
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      14.4G      1.637      10.59       2.13         83       1024: 100%|██████████| 340/340 [07:05<00:00,  1.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:18<00:00,  1.05it/s]
#                    all        603       1646      0.425      0.326      0.301      0.125
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      14.4G      1.622       10.4      2.114         47       1024: 100%|██████████| 340/340 [07:05<00:00,  1.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:18<00:00,  1.05it/s]
#                    all        603       1646      0.424      0.345      0.313      0.127
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      14.5G      1.604      10.22      2.098         84       1024: 100%|██████████| 340/340 [07:05<00:00,  1.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:18<00:00,  1.05it/s]
#                    all        603       1646      0.416      0.365      0.332      0.139
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      14.5G      1.592      9.947      2.077         56       1024: 100%|██████████| 340/340 [07:05<00:00,  1.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:18<00:00,  1.05it/s]
#                    all        603       1646       0.43      0.422      0.369      0.153
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      14.5G      1.569      9.826      2.055         72       1024: 100%|██████████| 340/340 [07:05<00:00,  1.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:18<00:00,  1.05it/s]
#                    all        603       1646      0.448      0.396       0.38      0.158
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      14.4G      1.567      9.723      2.053         68       1024: 100%|██████████| 340/340 [07:05<00:00,  1.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:17<00:00,  1.06it/s]
#                    all        603       1646      0.446      0.421      0.373       0.16
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      14.4G      1.552      9.536      2.028         67       1024: 100%|██████████| 340/340 [07:05<00:00,  1.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:18<00:00,  1.05it/s]
#                    all        603       1646      0.456      0.401       0.38      0.163
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      14.3G      1.554      9.522      2.039         67       1024: 100%|██████████| 340/340 [07:05<00:00,  1.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:18<00:00,  1

# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/tal.py in forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      83         try:
# ---> 84             return self._forward(pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      85         except torch.cuda.OutOfMemoryError:
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/tal.py in _forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#     110         """
# --> 111         mask_pos, align_metric, overlaps = self.get_pos_mask(
#     112             pd_scores, pd_bboxes, gt_labels, gt_bboxes, anc_points, mask_gt
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/tal.py in get_pos_mask(self, pd_scores, pd_bboxes, gt_labels, gt_bboxes, anc_points, mask_gt)
#     147         # Get anchor_align metric, (b, max_num_obj, h*w)
# --> 148         align_metric, overlaps = self.get_box_metrics(pd_scores, pd_bboxes, gt_labels, gt_bboxes, mask_in_gts * mask_gt)
#     149         # Get topk_metric mask, (b, max_num_obj, h*w)
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/tal.py in get_box_metrics(self, pd_scores, pd_bboxes, gt_labels, gt_bboxes, mask_gt)
#     184         gt_boxes = gt_bboxes.unsqueeze(2).expand(-1, -1, na, -1)[mask_gt]
# --> 185         overlaps[mask_gt] = self.iou_calculation(gt_boxes, pd_boxes)
#     186
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/tal.py in iou_calculation(self, gt_bboxes, pd_bboxes)
#     200         """
# --> 201         return bbox_iou(gt_bboxes, pd_bboxes, xywh=False, CIoU=True).squeeze(-1).clamp_(0)
#     202
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/metrics.py in bbox_iou(box1, box2, xywh, GIoU, DIoU, CIoU, eps)
#     114         b2_x1, b2_y1, b2_x2, b2_y2 = box2.chunk(4, -1)
# --> 115         w1, h1 = b1_x2 - b1_x1, b1_y2 - b1_y1 + eps
#     116         w2, h2 = b2_x2 - b2_x1, b2_y2 - b2_y1 + eps
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 2.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 2.12 MiB is free. Process 55838 has 14.73 GiB memory in use. Of the allocated memory 13.58 GiB is allocated by PyTorch, and 1012.46 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
#
# During handling of the above exception, another exception occurred:
#
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipython-input-2-851073476.py in <cell line: 0>()
#       4 model = YOLO('yolov8m.pt')
#       5
# ----> 6 model.train(
#       7     data='/content/drive/MyDrive/USC-Hackathon/project/data.yaml',
#       8     epochs=100,
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     797
#     798         self.trainer.hub_session = self.session  # attach optional HUB session
# --> 799         self.trainer.train()
#     800         # Update model and cfg after training
#     801         if RANK in {-1, 0}:
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/trainer.py in train(self)
#     225
#     226         else:
# --> 227             self._do_train(world_size)
#     228
#     229     def _setup_scheduler(self):
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/trainer.py in _do_train(self, world_size)
#     404                 with autocast(self.amp):
#     405                     batch = self.preprocess_batch(batch)
# --> 406                     loss, self.loss_items = self.model(batch)
#     407                     self.loss = loss.sum()
#     408                     if RANK != -1:
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py in forward(self, x, *args, **kwargs)
#     136         """
#     137         if isinstance(x, dict):  # for cases of training and validating while training.
# --> 138             return self.loss(x, *args, **kwargs)
#     139         return self.predict(x, *args, **kwargs)
#     140
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py in loss(self, batch, preds)
#     338
#     339         preds = self.forward(batch["img"]) if preds is None else preds
# --> 340         return self.criterion(preds, batch)
#     341
#     342     def init_criterion(self):
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/loss.py in __call__(self, preds, batch)
#     268         # dfl_conf = (dfl_conf.amax(-1).mean(-1) + dfl_conf.amax(-1).amin(-1)) / 2
#     269
# --> 270         _, target_bboxes, target_scores, fg_mask, _ = self.assigner(
#     271             # pred_scores.detach().sigmoid() * 0.8 + dfl_conf.unsqueeze(-1) * 0.2,
#     272             pred_scores.detach().sigmoid(),
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/tal.py in forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)
#      88             cpu_tensors = [t.cpu() for t in (pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)]
#      89             result = self._forward(*cpu_tensors)
# ---> 90             return tuple(t.to(device) for t in result)
#      91
#      92     def _forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt):
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/utils/tal.py in <genexpr>(.0)
#      88             cpu_tensors = [t.cpu() for t in (pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt)]
#      89             result = self._forward(*cpu_tensors)
# ---> 90             return tuple(t.to(device) for t in result)
#      91
#      92     def _forward(self, pd_scores, pd_bboxes, anc_points, gt_labels, gt_bboxes, mask_gt):
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 2.00 MiB. GPU 0 has a total capacity of 14.74 GiB of which 2.12 MiB is free. Process 55838 has 14.73 GiB memory in use. Of the allocated memory 13.59 GiB is allocated by PyTorch, and 999.20 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
