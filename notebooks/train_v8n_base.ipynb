# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 1st
# - f1-score: 0.3xx

# %%
#1
from ultralytics import YOLO

# 모델 생성 (YOLOv8n: 경량 모델, 필요시 s/m/l로 조정 가능)
model = YOLO('yolov8n.pt')  # 또는 yolov8s.pt, yolov8m.pt 등

# 학습 시작
model.train(
    data='/content/drive/MyDrive/USC-Hackathon/project/data.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    project='/content/drive/MyDrive/USC-Hackathon/project',
    name='rdm_v8n_50ep_defaug_box1cls1dfl1_base',
    pretrained=True,
    save=True
)
