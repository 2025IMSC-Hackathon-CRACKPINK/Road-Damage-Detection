# %% [markdown]
# # YOLO Training for Road Damage Detection
#
# Training YOLO model for road damage detection: Pothole, Alligator Crack, Transverse Crack, Longitudinal Crack

# %%
# Install and import required packages
# %pip install ultralytics -q

import os
import yaml
import shutil
import random
import torch
from glob import glob
from ultralytics import YOLO

# Check CUDA availability
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"Number of GPUs: {torch.cuda.device_count()}")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# CUDA available: True
# Number of GPUs: 8

# %%
# Load YOLO11m model
model = YOLO('yolo11m.pt')

# %%
# Train YOLO model with multi-GPU support
import os

# Set up multi-GPU environment
os.environ['CUDA_VISIBLE_DEVICES'] = '1,2,3,4,5,6,7'
num_gpus = len(os.environ['CUDA_VISIBLE_DEVICES'].split(','))
base_batch_size = 16
total_batch_size = base_batch_size * num_gpus

results = model.train(
    data='yolo_augmented_dataset/data.yaml',
    epochs=100,
    imgsz=640,
    batch=total_batch_size,
    device=[1, 2, 3, 4, 5, 6, 7],
    project='runs',
    name='road_damage_detection_multigpu',
    workers=8 * num_gpus,
    patience=15,
    save_period=10,
    amp=True,
    cache=True,
    cos_lr=True,
    verbose=True
)
# Out:
# Ultralytics 8.3.169 🚀 Python-3.12.11 torch-2.6.0+cu124 CUDA:1 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:2 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:3 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:4 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:5 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:6 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:7 (NVIDIA GeForce RTX 3090, 24253MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=112, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=yolo_augmented_dataset/data.yaml, degrees=0.0, deterministic=True, device=1,2,3,4,5,6,7, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=road_damage_detection_multigpu7, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/road_damage_detection_multigpu7, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=56, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1414108  ultralytics.nn.modules.head.Detect           [4, [256, 512, 512]]
# YOLO11m summary: 231 layers, 20,056,092 parameters, 20,056,076 gradients, 68.2 GFLOPs
#
# Transferred 649/649 items from pretrained weights
# DDP: debug command /home/kwdahun/anaconda3/envs/yolo_env/bin/python -m torch.distributed.run --nproc_per_node 7 --master_port 44477 /home/kwdahun/.config/Ultralytics/DDP/_temp_0xrmb6d1123945042350192.py
# Ultralytics 8.3.169 🚀 Python-3.12.11 torch-2.6.0+cu124 CUDA:1 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:2 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:3 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:4 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:5 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:6 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:7 (NVIDIA GeForce RTX 3090, 24253MiB)
# Overriding model.yaml nc=80 with nc=4
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2639.5±1189.5 MB/s, size: 112.4 KB)
# train: Scanning /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_augmented_dataset/train/labels... 16908 images, 0 backgrounds, 0 corrupt: 100%|██████████| 16908/16908 [00:13<00:00, 1244.01it/s]
# train: New cache created: /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_augmented_dataset/train/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (19.3GB RAM): 100%|██████████| 16908/16908 [00:07<00:00, 2139.24it/s]
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1222.1±736.3 MB/s, size: 180.1 KB)
# val: Scanning /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_augmented_dataset/val/labels... 3624 images, 0 backgrounds, 0 corrupt: 100%|██████████| 3624/3624 [00:02<00:00, 1230.23it/s]
# val: New cache created: /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_augmented_dataset/val/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (4.1GB RAM): 100%|██████████| 3624/3624 [00:02<00:00, 1339.75it/s]
# Plotting labels to runs/road_damage_detection_multigpu7/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.000875), 112 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 63 dataloader workers
# Logging results to runs/road_damage_detection_multigpu7
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      7.89G      2.198      3.196      2.013         53        640: 100%|██████████| 151/151 [01:02<00:00,  2.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 114/114 [00:19<00:00,  5.72it/s]
#                    all       3624       9816      0.385       0.33      0.283      0.124
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      9.45G      1.914      2.131      1.691         74        640: 100%|██████████| 151/151 [01:00<00:00,  2.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 114/114 [00:19<00:00,  5.75it/s]
#                    all       3624       9816      0.337      0.321       0.25      0.105
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      9.49G      2.002      2.275      1.768         65        640: 100%|██████████| 151/151 [01:01<00:00,  2.47it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 114/114 [00:19<00:00,  5.71it/s]
#                    all       3624       9816      0.153      0.123     0.0582     0.0214
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      9.53G      2.044      2.379      1.851         55        640: 100%|██████████| 151/151 [01:01<00:00,  2.46it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 114/114 [00:20<00:00,  5.48it/s]
#                    all       3624       9816      0.289      0.241      0.163     0.0588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      9.58G      2.065      2.376      1.876         60        640:   8%|▊         | 12/151 [00:04<00:56,  2.48it/s]W0724 03:44:59.143000 962979 site-packages/torch/distributed/elastic/agent/server/api.py:719] Received 2 death signal, shutting down workers
# W0724 03:44:59.145000 962979 site-packages/torch/distributed/elastic/multiprocessing/api.py:897] Sending process 962985 closing signal SIGINT
# Process Process-9:
# Process Process-17:
# Process Process-11:
# Process Process-12:
# Process Process-15:
# Process Process-1:
# Process Process-5:
# Traceback (most recent call last):
# Process Process-7:
# Process Process-8:
# Process Process-18:
# Process Process-10:
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 132, in _remove_temp_dir
#     def _remove_temp_dir(rmtree, tempdir):
#
# Traceback (most recent call last):
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process Process-13:
# Process Process-4:
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 136, in _remove_temp_dir
#     rmtree(tempdir, onerror=onerror)
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/shutil.py", line 759, in rmtree
#     _rmtree_safe_fd(stack, onexc)
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/shutil.py", line 662, in _rmtree_safe_fd
#     os.rmdir(name, dir_fd=dirfd)
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 337, in _exit_function
#     _run_finalizers(0)
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 136, in _remove_temp_dir
#     rmtree(tempdir, onerror=onerror)
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/shutil.py", line 759, in rmtree
#     _rmtree_safe_fd(stack, onexc)
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/shutil.py", line 683, in _rmtree_safe_fd
#     stack.append((os.close, topfd, path, orig_entry))
# KeyboardInterrupt
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
# W0724 03:44:59.150000 962979 site-packages/torch/distributed/elastic/multiprocessing/api.py:897] Sending process 962986 closing signal SIGINT
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Traceback (most recent call last):
# KeyboardInterrupt
# W0724 03:44:59.151000 962979 site-packages/torch/distributed/elastic/multiprocessing/api.py:897] Sending process 962987 closing signal SIGINT
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# W0724 03:44:59.151000 962979 site-packages/torch/distributed/elastic/multiprocessing/api.py:897] Sending process 962988 closing signal SIGINT
# Process Process-9:
# Traceback (most recent call last):
# Process Process-9:
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
# W0724 03:44:59.151000 962979 site-packages/torch/distributed/elastic/multiprocessing/api.py:897] Sending process 962989 closing signal SIGINT
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# W0724 03:44:59.152000 962979 site-packages/torch/distributed/elastic/multiprocessing/api.py:897] Sending process 962990 closing signal SIGINT
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
# W0724 03:44:59.152000 962979 site-packages/torch/distributed/elastic/multiprocessing/api.py:897] Sending process 962991 closing signal SIGINT
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 136, in _remove_temp_dir
#     rmtree(tempdir, onerror=onerror)
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/shutil.py", line 759, in rmtree
#     _rmtree_safe_fd(stack, onexc)
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/shutil.py", line 674, in _rmtree_safe_fd
#     topfd = os.open(name, os.O_RDONLY | os.O_NONBLOCK, dir_fd=dirfd)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 136, in _remove_temp_dir
#     rmtree(tempdir, onerror=onerror)
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/shutil.py", line 759, in rmtree
#     _rmtree_safe_fd(stack, onexc)
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/shutil.py", line 674, in _rmtree_safe_fd
#     topfd = os.open(name, os.O_RDONLY | os.O_NONBLOCK, dir_fd=dirfd)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 136, in _remove_temp_dir
#     rmtree(tempdir, onerror=onerror)
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/shutil.py", line 731, in rmtree
#     sys.audit("shutil.rmtree", path, dir_fd)
# KeyboardInterrupt
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/multiprocessing/queues.py", line 219, in _finalize_join
#     thread.join()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/threading.py", line 1149, in join
#     self._wait_for_tstate_lock()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/threading.py", line 1171, in _wait_for_tstate_lock
#     self._stop()
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/threading.py", line 1081, in _stop
#     def _stop(self):
#
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 10
#       7 base_batch_size = 16
#       8 total_batch_size = base_batch_size * num_gpus
# ---> 10 results = model.train(
#      11     data='yolo_augmented_dataset/data.yaml',
#      12     epochs=100,
#      13     imgsz=640,
#      14     batch=total_batch_size,
#      15     device=[1, 2, 3, 4, 5, 6, 7],
#      16     project='runs',
#      17     name='road_damage_detection_multigpu',
#      18     workers=8 * num_gpus,
#      19     patience=15,
#      20     save_period=10,
#      21     amp=True,
#      22     cache=True,
#      23     cos_lr=True,
#      24     verbose=True
#      25 )
#
# File ~/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/model.py:799, in Model.train(self, trainer, **kwargs)
#     796     self.model = self.trainer.model
#     798 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 799 self.trainer.train()
#     800 # Update model and cfg after training
#     801 if RANK in {-1, 0}:
#
# File ~/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py:220, in BaseTrainer.train(self)
#     218 try:
#     219     LOGGER.info(f"{colorstr('DDP:')} debug command {' '.join(cmd)}")
# --> 220     subprocess.run(cmd, check=True)
#     221 except Exception as e:
#     222     raise e
#
# File ~/anaconda3/envs/yolo_env/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File ~/anaconda3/envs/yolo_env/lib/python3.12/subprocess.py:1201, in Popen.communicate(self, input, timeout)
#    1199         stderr = self.stderr.read()
#    1200         self.stderr.close()
# -> 1201     self.wait()
#    1202 else:
#    1203     if timeout is not None:
#
# File ~/anaconda3/envs/yolo_env/lib/python3.12/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File ~/anaconda3/envs/yolo_env/lib/python3.12/subprocess.py:2053, in Popen._wait(self, timeout)
#    2051 if self.returncode is not None:
#    2052     break  # Another thread waited.
# -> 2053 (pid, sts) = self._try_wait(0)
#    2054 # Check the pid and loop as waitpid has been known to
#    2055 # return 0 even without WNOHANG in odd situations.
#    2056 # http://bugs.python.org/issue14396.
#    2057 if pid == self.pid:
#
# File ~/anaconda3/envs/yolo_env/lib/python3.12/subprocess.py:2011, in Popen._try_wait(self, wait_flags)
#    2009 """All callers to this function MUST hold self._waitpid_lock."""
#    2010 try:
# -> 2011     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2012 except ChildProcessError:
#    2013     # This happens if SIGCLD is set to be ignored or waiting
#    2014     # for child processes has otherwise been disabled for our
#    2015     # process.  This child is dead, we can't get the status.
#    2016     pid = self.pid
#
# KeyboardInterrupt:
# [rank3]: Traceback (most recent call last):
# [rank3]:   File "/home/kwdahun/.config/Ultralytics/DDP/_temp_0xrmb6d1123945042350192.py", line 13, in <module>
# [rank3]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 227, in train
# [rank3]:     self._do_train(world_size)
# [rank3]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 415, in _do_train
# [rank3]:     self.scaler.scale(self.loss).backward()
# [rank3]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/_tensor.py", line 626, in backward
# [rank3]:     torch.autograd.backward(
# [rank3]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/autograd/__init__.py", line 347, in backward
# [rank3]:     _engine_run_backward(
# [rank3]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/autograd/graph.py", line 823, in _engine_run_backward
# [rank3]:     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [rank3]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank3]: KeyboardInterrupt
# [rank5]: Traceback (most recent call last):
# [rank5]:   File "/home/kwdahun/.config/Ultralytics/DDP/_temp_0xrmb6d1123945042350192.py", line 13, in <module>
# [rank5]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 227, in train
# [rank5]:     self._do_train(world_size)
# [rank5]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 415, in _do_train
# [rank5]:     self.scaler.scale(self.loss).backward()
# [rank5]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/_tensor.py", line 626, in backward
# [rank5]:     torch.autograd.backward(
# [rank5]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/autograd/__init__.py", line 347, in backward
# [rank5]:     _engine_run_backward(
# [rank5]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/autograd/graph.py", line 823, in _engine_run_backward
# [rank5]:     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [rank5]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank5]: KeyboardInterrupt
# [rank2]: Traceback (most recent call last):
# [rank2]:   File "/home/kwdahun/.config/Ultralytics/DDP/_temp_0xrmb6d1123945042350192.py", line 13, in <module>
# [rank2]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 227, in train
# [rank2]:     self._do_train(world_size)
# [rank2]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 415, in _do_train
# [rank2]:     self.scaler.scale(self.loss).backward()
# [rank2]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/_tensor.py", line 626, in backward
# [rank2]:     torch.autograd.backward(
# [rank2]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/autograd/__init__.py", line 347, in backward
# [rank2]:     _engine_run_backward(
# [rank2]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/autograd/graph.py", line 823, in _engine_run_backward
# [rank2]:     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [rank2]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank2]: KeyboardInterrupt
# [rank1]: Traceback (most recent call last):
# [rank1]:   File "/home/kwdahun/.config/Ultralytics/DDP/_temp_0xrmb6d1123945042350192.py", line 13, in <module>
# [rank1]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 227, in train
# [rank1]:     self._do_train(world_size)
# [rank1]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 415, in _do_train
# [rank1]:     self.scaler.scale(self.loss).backward()
# [rank1]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/_tensor.py", line 626, in backward
# [rank1]:     torch.autograd.backward(
# [rank1]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/autograd/__init__.py", line 347, in backward
# [rank1]:     _engine_run_backward(
# [rank1]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/autograd/graph.py", line 823, in _engine_run_backward
# [rank1]:     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [rank1]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank1]: KeyboardInterrupt
#       5/100      9.58G      2.065      2.376      1.876         60        640:   8%|▊         | 12/151 [00:05<01:03,  2.20it/s]
# [rank6]: Traceback (most recent call last):
# [rank6]:   File "/home/kwdahun/.config/Ultralytics/DDP/_temp_0xrmb6d1123945042350192.py", line 13, in <module>
# [rank6]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 227, in train
# [rank6]:     self._do_train(world_size)
# [rank6]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 415, in _do_train
# [rank6]:     self.scaler.scale(self.loss).backward()
# [rank6]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/_tensor.py", line 626, in backward
# [rank6]:     torch.autograd.backward(
# [rank6]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/autograd/__init__.py", line 347, in backward
# [rank6]:     _engine_run_backward(
# [rank6]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/autograd/graph.py", line 823, in _engine_run_backward
# [rank6]:     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [rank6]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank6]: KeyboardInterrupt
# [rank4]: Traceback (most recent call last):
# [rank4]:   File "/home/kwdahun/.config/Ultralytics/DDP/_temp_0xrmb6d1123945042350192.py", line 13, in <module>
# [rank4]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 227, in train
# [rank4]:     self._do_train(world_size)
# [rank4]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 415, in _do_train
# [rank4]:     self.scaler.scale(self.loss).backward()
# [rank4]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/_tensor.py", line 626, in backward
# [rank4]:     torch.autograd.backward(
# [rank4]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/autograd/__init__.py", line 347, in backward
# [rank4]:     _engine_run_backward(
# [rank4]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/autograd/graph.py", line 823, in _engine_run_backward
# [rank4]:     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [rank4]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank4]: KeyboardInterrupt
# [rank0]: Traceback (most recent call last):
# [rank0]:   File "/home/kwdahun/.config/Ultralytics/DDP/_temp_0xrmb6d1123945042350192.py", line 13, in <module>
# [rank0]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 227, in train
# [rank0]:     self._do_train(world_size)
# [rank0]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 415, in _do_train
# [rank0]:     self.scaler.scale(self.loss).backward()
# [rank0]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/_tensor.py", line 626, in backward
# [rank0]:     torch.autograd.backward(
# [rank0]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/autograd/__init__.py", line 347, in backward
# [rank0]:     _engine_run_backward(
# [rank0]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/autograd/graph.py", line 823, in _engine_run_backward
# [rank0]:     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [rank0]:            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank0]: KeyboardInterrupt

# %%
# Evaluate model
print("Evaluating model...")

# # Load the best model from training
# train_dirs = sorted(glob('runs/detect/road_damage_detection_multigpu*'), key=os.path.getmtime, reverse=True)
# if train_dirs:
#     best_model_path = f"{train_dirs[0]}/weights/best.pt"
#     print(f"Loading best model from: {best_model_path}")
#     eval_model = YOLO(best_model_path)
# else:
#     print("Using current model for evaluation")
#     eval_model = model

eval_model = YOLO('runs/road_damage_detection_multigpu4/weights/best.pt')

# Evaluate on test set
results = eval_model.val(
    data='yolo_dataset/data.yaml', 
    split='test',
    device=0,
    verbose=True
)

# Print metrics
print(f"\nmAP@0.5:      {results.box.map50:.4f}")
print(f"mAP@0.5:0.95: {results.box.map:.4f}")
print(f"Precision:    {results.box.mp:.4f}")
print(f"Recall:       {results.box.mr:.4f}")
print(f"Detailed results saved to: {results.save_dir}")
# Out:
# Evaluating model...
# Ultralytics 8.3.169 🚀 Python-3.12.11 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3090, 24253MiB)
# Ultralytics 8.3.169 🚀 Python-3.12.11 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3090, 24253MiB)
# YOLO11m summary (fused): 125 layers, 20,033,116 parameters, 0 gradients, 67.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2213.3±553.0 MB/s, size: 65.9 KB)
# YOLO11m summary (fused): 125 layers, 20,033,116 parameters, 0 gradients, 67.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2213.3±553.0 MB/s, size: 65.9 KB)
# val: Scanning /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_dataset/test/labels.cache... 906 images, 0 backgrounds, 0 corrupt: 100%|██████████| 906/906 [00:00<?, ?it/s]
# val: Scanning /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_dataset/test/labels.cache... 906 images, 0 backgrounds, 0 corrupt: 100%|██████████| 906/906 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 57/57 [00:08<00:00,  6.93it/s]
#                    all        906       2491      0.588      0.538      0.562      0.259
#                Pothole        285        530      0.601      0.479      0.513      0.217
#        Alligator Crack        436        531      0.583      0.605       0.63      0.301
#       Transverse Crack        416        668      0.613      0.479      0.546       0.24
#     Longitudinal Crack        476        762      0.556      0.588       0.56      0.277
# Speed: 0.1ms preprocess, 5.2ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/detect/val3
#                Pothole        285        530      0.601      0.479      0.513      0.217
#        Alligator Crack        436        531      0.583      0.605       0.63      0.301
#       Transverse Crack        416        668      0.613      0.479      0.546       0.24
#     Longitudinal Crack        476        762      0.556      0.588       0.56      0.277
# Speed: 0.1ms preprocess, 5.2ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/detect/val3
#
# mAP@0.5:      0.5624
# mAP@0.5:0.95: 0.2586
# Precision:    0.5884
# Recall:       0.5377
# Detailed results saved to: runs/detect/val3
#
# mAP@0.5:      0.5624
# mAP@0.5:0.95: 0.2586
# Precision:    0.5884
# Recall:       0.5377
# Detailed results saved to: runs/detect/val3

# %%
# Save best model
train_dirs = sorted(glob('runs/detect/road_damage_detection*'), key=os.path.getmtime, reverse=True)
if train_dirs:
    best_model_path = f"{train_dirs[0]}/weights/best.pt"
    os.makedirs('yolo_checkpoints', exist_ok=True)
    shutil.copy(best_model_path, 'yolo_checkpoints/best_road_damage.pt')
    print(f"Model saved: yolo_checkpoints/best_road_damage.pt")

# %%
# Inference on test images
from pathlib import Path
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Load the best trained model
def load_best_model():
    """Load the best model from training runs"""
    train_dirs = sorted(glob('runs/detect/road_damage_detection*'), key=os.path.getmtime, reverse=True)
    if train_dirs:
        best_model_path = f"{train_dirs[0]}/weights/best.pt"
        print(f"Loading model from: {best_model_path}")
        return YOLO(best_model_path)
    elif os.path.exists('yolo_checkpoints/best_road_damage.pt'):
        print("Loading model from: yolo_checkpoints/best_road_damage.pt")
        return YOLO('yolo_checkpoints/best_road_damage.pt')
    else:
        print("No trained model found. Using base model.")
        return YOLO('yolo11m.pt')

# Example inference
if True:  # Set to True to run inference
    # Load trained model
    trained_model = load_best_model()
    
    # Example: Inference on test images
    test_images = glob('yolo_dataset/test/images/*.jpg')[:5]  # First 5 test images
    
    if test_images:
        print(f"Running inference on {len(test_images)} test images...")
        
        # Single image inference
        result = trained_model(test_images[0], device=0)
        
        # Display result
        annotated_img = result[0].plot()
        plt.figure(figsize=(12, 8))
        plt.imshow(cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB))
        plt.title(f"Detection Result: {Path(test_images[0]).name}")
        plt.axis('off')
        plt.show()
        
        # Print detection details
        boxes = result[0].boxes
        if boxes is not None:
            class_names = ['Pothole', 'Alligator Crack', 'Transverse Crack', 'Longitudinal Crack']
            print(f"\nDetections in {Path(test_images[0]).name}:")
            for i, (cls, conf) in enumerate(zip(boxes.cls, boxes.conf)):
                print(f"  {class_names[int(cls)]}: {conf:.3f}")
        else:
            print("No detections found")
    else:
        print("No test images found. Please check the dataset.")
