# %% [markdown]
# # YOLO Training for Road Damage Detection
#
# Training YOLO model for road damage detection: Pothole, Alligator Crack, Transverse Crack, Longitudinal Crack

# %%
# Install and import required packages
# %pip install ultralytics -q

import os
import yaml
import shutil
import random
import torch
from glob import glob
from ultralytics import YOLO

# Check CUDA availability
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"Number of GPUs: {torch.cuda.device_count()}")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# CUDA available: True
# Number of GPUs: 8

# %%
# Load YOLO11m model
model = YOLO('yolo12m.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo12m.pt to 'yolo12m.pt'...
# 100%|██████████| 39.0M/39.0M [00:03<00:00, 11.8MB/s]

# %%
# Train YOLO model with multi-GPU support
import os

# Set up multi-GPU environment
gpus = [1, 2, 3, 4, 5, 6, 7]
os.environ['CUDA_VISIBLE_DEVICES'] = ','.join(map(str, gpus))
num_gpus = len(gpus)
base_batch_size = 32
total_batch_size = base_batch_size * num_gpus

results = model.train(
    data='yolo_dataset/data.yaml',
    epochs=600,
    imgsz=640,
    batch=total_batch_size,
    device=gpus,
    project='runs',
    name='road_damage_detection',
    workers=8 * num_gpus,
    patience=30,
    save_period=10,
    amp=True,
    cache=True,
    cos_lr=True,
    verbose=True,
    scale=0.9,
    mosaic=1.0,
    mixup=0.0,
    copy_paste=0.4,
    hsv_h=0.015,      # Hue augmentation
    hsv_s=0.7,        # Saturation augmentation  
    hsv_v=0.4,        # Value/brightness augmentation
    translate=0.1,    # Translation augmentation
    shear=2.0,        # Shear augmentation
    perspective=0.0,  # Perspective augmentation
    flipud=0.0,       # Vertical flip (usually 0 for road damage)
)
# Out:
# Ultralytics 8.3.169 🚀 Python-3.12.11 torch-2.6.0+cu124 CUDA:1 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:2 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:3 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:4 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:5 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:6 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:7 (NVIDIA GeForce RTX 3090, 24253MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=224, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.4, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=yolo_dataset/data.yaml, degrees=0.0, deterministic=True, device=1,2,3,4,5,6,7, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=600, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=road_damage_detection2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/road_damage_detection2, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.9, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=56, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 4]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2689536  ultralytics.nn.modules.block.A2C2f           [512, 512, 2, True, 1]
#   9                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  10             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  11                  -1  1   1248768  ultralytics.nn.modules.block.A2C2f           [1024, 512, 1, False, -1]
#  12                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  13             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  14                  -1  1    378624  ultralytics.nn.modules.block.A2C2f           [1024, 256, 1, False, -1]
#  15                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  16            [-1, 11]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1   1183232  ultralytics.nn.modules.block.A2C2f           [768, 512, 1, False, -1]
#  18                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  19             [-1, 8]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  21        [14, 17, 20]  1   1414108  ultralytics.nn.modules.head.Detect           [4, [256, 512, 512]]
# YOLOv12m summary: 292 layers, 20,140,572 parameters, 20,140,556 gradients, 67.8 GFLOPs
#
# Transferred 751/751 items from pretrained weights
# DDP: debug command /home/kwdahun/anaconda3/envs/yolo_env/bin/python -m torch.distributed.run --nproc_per_node 7 --master_port 49017 /home/kwdahun/.config/Ultralytics/DDP/_temp_gwlz58h6137361450410896.py
# WARNING ⚠️ Error decoding JSON from /home/kwdahun/.config/Ultralytics/settings.json. Starting with an empty dictionary.
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/kwdahun/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.169 🚀 Python-3.12.11 torch-2.6.0+cu124 CUDA:1 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:2 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:3 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:4 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:5 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:6 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:7 (NVIDIA GeForce RTX 3090, 24253MiB)
# Overriding model.yaml nc=80 with nc=4
# Transferred 745/751 items from pretrained weights
# Freezing layer 'model.21.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1317.7±551.0 MB/s, size: 73.4 KB)
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Scanning /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_dataset/train/labels.cache... 4227 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4227/4227 [00:00<?, ?it/s]
# train: Caching images (4.8GB RAM): 100%|██████████| 4227/4227 [00:01<00:00, 2377.13it/s]
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 768.2±957.3 MB/s, size: 72.3 KB)
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val:
0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     140/600      21.7G      1.471      1.092      1.323        154        640: 100%|██████████| 19/19 [00:12<00:00,  1.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.72it/s]
#                    all        906       2454      0.565      0.486       0.48      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     141/600      21.8G      1.495      1.121      1.354        105        640: 100%|██████████| 19/19 [00:12<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        906       2454      0.576      0.504      0.505      0.227
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     142/600      21.8G      1.496      1.122      1.328        115        640: 100%|██████████| 19/19 [00:12<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.72it/s]
#                    all        906       2454      0.543       0.51      0.498      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     143/600      21.8G      1.482      1.103      1.311        194        640: 100%|██████████| 19/19 [00:12<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        906       2454      0.561      0.527      0.514      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     144/600      21.7G      1.504      1.129      1.324        155        640: 100%|██████████| 19/19 [00:12<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        906       2454      0.558      0.532      0.515      0.232
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     145/600      21.8G      1.454      1.101      1.344        146        640: 100%|██████████| 19/19 [00:12<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.70it/s]
#                    all        906       2454      0.566      0.514        0.5      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     146/600      21.8G      1.473      1.093      1.322        113        640: 100%|██████████| 19/19 [00:12<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        906       2454      0.588      0.505      0.513      0.231
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     147/600      21.8G      1.476      1.119      1.313        133        640: 100%|██████████| 19/19 [00:12<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        906       2454      0.596      0.486      0.502      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     148/600      21.7G      1.439      1.072      1.295        130        640: 100%|██████████| 19/19 [00:12<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        906       2454      0.571      0.512      0.508      0.229
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     149/600      21.7G      1.468      1.102       1.32        117        640: 100%|██████████| 19/19 [00:12<00:00,  1.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.72it/s]
#                    all        906       2454      0.539      0.531      0.493      0.219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     150/600      21.8G       1.43      1.074      1.311        125        640: 100%|██████████| 19/19 [00:12<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        906       2454      0.552      0.523      0.502      0.225
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     151/600      21.8G      1.449       1.08      1.326        138        640: 100%|██████████| 19/19 [00:12<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        906       2454       0.54      0.535      0.514      0.231
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     152/600      21.7G       1.46      1.077      1.325        138        640: 100%|██████████| 19/19 [00:12<00:00,  1.53it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:05<00:00,  2.71it/s]
#                    all        906       2454      0.543      0.531      0.497      0.224
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 122, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 152 epochs completed in 0.815 hours.
# Optimizer stripped from runs/road_damage_detection2/weights/last.pt, 40.8MB
# Optimizer stripped from runs/road_damage_detection2/weights/best.pt, 40.8MB
#
# Validating runs/road_damage_detection2/weights/best.pt...
# Ultralytics 8.3.169 🚀 Python-3.12.11 torch-2.6.0+cu124 CUDA:1 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:2 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:3 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:4 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:5 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:6 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:7 (NVIDIA GeForce RTX 3090, 24253MiB)
# YOLOv12m summary (fused): 169 layers, 20,107,996 parameters, 0 gradients, 67.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 15/15 [00:06<00:00,  2.34it/s]
#                    all        906       2454        0.6      0.516      0.531      0.238
#                Pothole        262        486      0.583      0.409      0.445      0.154
#        Alligator Crack        414        509      0.633      0.525      0.567      0.281
#       Transverse Crack        439        684      0.585       0.59      0.573       0.25
#     Longitudinal Crack        482        775      0.599      0.541      0.539      0.269
# Speed: 0.1ms preprocess, 3.8ms inference, 0.0ms loss, 1.0ms postprocess per image
# Results saved to runs/road_damage_detection2

# %%
# Evaluate model
print("Evaluating model...")

# # Load the best model from training
# train_dirs = sorted(glob('runs/detect/road_damage_detection_multigpu*'), key=os.path.getmtime, reverse=True)
# if train_dirs:
#     best_model_path = f"{train_dirs[0]}/weights/best.pt"
#     print(f"Loading best model from: {best_model_path}")
#     eval_model = YOLO(best_model_path)
# else:
#     print("Using current model for evaluation")
#     eval_model = model

eval_model = YOLO('runs/road_damage_detection_multigpu4/weights/best.pt')

# Evaluate on test set
results = eval_model.val(
    data='yolo_dataset/data.yaml', 
    split='test',
    device=0,
    verbose=True
)

# Print metrics
print(f"\nmAP@0.5:      {results.box.map50:.4f}")
print(f"mAP@0.5:0.95: {results.box.map:.4f}")
print(f"Precision:    {results.box.mp:.4f}")
print(f"Recall:       {results.box.mr:.4f}")
print(f"Detailed results saved to: {results.save_dir}")
# Out:
# Evaluating model...
# Ultralytics 8.3.169 🚀 Python-3.12.11 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3090, 24253MiB)
# Ultralytics 8.3.169 🚀 Python-3.12.11 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3090, 24253MiB)
# YOLO11m summary (fused): 125 layers, 20,033,116 parameters, 0 gradients, 67.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2213.3±553.0 MB/s, size: 65.9 KB)
# YOLO11m summary (fused): 125 layers, 20,033,116 parameters, 0 gradients, 67.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2213.3±553.0 MB/s, size: 65.9 KB)
# val: Scanning /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_dataset/test/labels.cache... 906 images, 0 backgrounds, 0 corrupt: 100%|██████████| 906/906 [00:00<?, ?it/s]
# val: Scanning /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_dataset/test/labels.cache... 906 images, 0 backgrounds, 0 corrupt: 100%|██████████| 906/906 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 57/57 [00:08<00:00,  6.93it/s]
#                    all        906       2491      0.588      0.538      0.562      0.259
#                Pothole        285        530      0.601      0.479      0.513      0.217
#        Alligator Crack        436        531      0.583      0.605       0.63      0.301
#       Transverse Crack        416        668      0.613      0.479      0.546       0.24
#     Longitudinal Crack        476        762      0.556      0.588       0.56      0.277
# Speed: 0.1ms preprocess, 5.2ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/detect/val3
#                Pothole        285        530      0.601      0.479      0.513      0.217
#        Alligator Crack        436        531      0.583      0.605       0.63      0.301
#       Transverse Crack        416        668      0.613      0.479      0.546       0.24
#     Longitudinal Crack        476        762      0.556      0.588       0.56      0.277
# Speed: 0.1ms preprocess, 5.2ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/detect/val3
#
# mAP@0.5:      0.5624
# mAP@0.5:0.95: 0.2586
# Precision:    0.5884
# Recall:       0.5377
# Detailed results saved to: runs/detect/val3
#
# mAP@0.5:      0.5624
# mAP@0.5:0.95: 0.2586
# Precision:    0.5884
# Recall:       0.5377
# Detailed results saved to: runs/detect/val3

# %%
# Save best model
train_dirs = sorted(glob('runs/detect/road_damage_detection*'), key=os.path.getmtime, reverse=True)
if train_dirs:
    best_model_path = f"{train_dirs[0]}/weights/best.pt"
    os.makedirs('yolo_checkpoints', exist_ok=True)
    shutil.copy(best_model_path, 'yolo_checkpoints/best_road_damage.pt')
    print(f"Model saved: yolo_checkpoints/best_road_damage.pt")

# %%
# Inference on test images
from pathlib import Path
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Load the best trained model
def load_best_model():
    """Load the best model from training runs"""
    train_dirs = sorted(glob('runs/detect/road_damage_detection*'), key=os.path.getmtime, reverse=True)
    if train_dirs:
        best_model_path = f"{train_dirs[0]}/weights/best.pt"
        print(f"Loading model from: {best_model_path}")
        return YOLO(best_model_path)
    elif os.path.exists('yolo_checkpoints/best_road_damage.pt'):
        print("Loading model from: yolo_checkpoints/best_road_damage.pt")
        return YOLO('yolo_checkpoints/best_road_damage.pt')
    else:
        print("No trained model found. Using base model.")
        return YOLO('yolo11m.pt')

# Example inference
if True:  # Set to True to run inference
    # Load trained model
    trained_model = load_best_model()
    
    # Example: Inference on test images
    test_images = glob('yolo_dataset/test/images/*.jpg')[:5]  # First 5 test images
    
    if test_images:
        print(f"Running inference on {len(test_images)} test images...")
        
        # Single image inference
        result = trained_model(test_images[0], device=0)
        
        # Display result
        annotated_img = result[0].plot()
        plt.figure(figsize=(12, 8))
        plt.imshow(cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB))
        plt.title(f"Detection Result: {Path(test_images[0]).name}")
        plt.axis('off')
        plt.show()
        
        # Print detection details
        boxes = result[0].boxes
        if boxes is not None:
            class_names = ['Pothole', 'Alligator Crack', 'Transverse Crack', 'Longitudinal Crack']
            print(f"\nDetections in {Path(test_images[0]).name}:")
            for i, (cls, conf) in enumerate(zip(boxes.cls, boxes.conf)):
                print(f"  {class_names[int(cls)]}: {conf:.3f}")
        else:
            print("No detections found")
    else:
        print("No test images found. Please check the dataset.")
