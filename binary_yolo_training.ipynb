# %% [markdown]
# # Binary YOLO Training for Road Damage Detection
#
# YOLOv8m model for binary classification: Road Damage vs No Road Damage

# %%
# %pip install ultralytics -q

import os
import yaml
import shutil
import random
import torch
from glob import glob
from ultralytics import YOLO

print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPUs: {torch.cuda.device_count()}")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# CUDA available: True
# GPUs: 8
# CUDA available: True
# GPUs: 8

# %%
binary_dataset_path = 'yolo_binary_dataset'
binary_augmented_path = 'yolo_binary_augmented_dataset'

if os.path.exists(f"{binary_dataset_path}/data.yaml"):
    print(f"✓ Binary dataset found: {binary_dataset_path}")
else:
    print(f"❌ Binary dataset not found. Run prepare_yolo_dataset.ipynb first")

if os.path.exists(f"{binary_augmented_path}/data.yaml"):
    print(f"✓ Binary augmented dataset found: {binary_augmented_path}")
else:
    print(f"❌ Binary augmented dataset not found")
# Out:
# ✓ Binary dataset found: yolo_binary_dataset
# ✓ Binary augmented dataset found: yolo_binary_augmented_dataset

# %%
model = YOLO('yolo11n.pt')

# %%
# dataset_path = binary_augmented_path 
dataset_path = binary_dataset_path 

gpu_ids = [1, 2, 3, 4, 5, 6, 7]
os.environ['CUDA_VISIBLE_DEVICES'] = ','.join(map(str, gpu_ids))
num_gpus = len(gpu_ids)
total_batch_size = 16 * num_gpus

results = model.train(
    data=f'{dataset_path}/data.yaml',
    epochs=150,
    imgsz=640,
    batch=total_batch_size,
    device=gpu_ids,
    project='runs/detect',
    name='binary_road_damage_detection',
    verbose=True
)
# Out:
# Ultralytics 8.3.169 🚀 Python-3.12.11 torch-2.6.0+cu124 CUDA:1 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:2 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:3 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:4 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:5 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:6 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:7 (NVIDIA GeForce RTX 3090, 24253MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=112, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=yolo_binary_dataset/data.yaml, degrees=0.0, deterministic=True, device=1,2,3,4,5,6,7, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=150, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=binary_road_damage_detection4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/binary_road_damage_detection4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    430867  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,035 parameters, 2,590,019 gradients, 6.4 GFLOPs
#
# Transferred 499/499 items from pretrained weights
# DDP: debug command /home/kwdahun/anaconda3/envs/yolo_env/bin/python -m torch.distributed.run --nproc_per_node 7 --master_port 39343 /home/kwdahun/.config/Ultralytics/DDP/_temp_fdrzvzq9125325136087136.py
# Ultralytics 8.3.169 🚀 Python-3.12.11 torch-2.6.0+cu124 CUDA:1 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:2 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:3 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:4 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:5 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:6 (NVIDIA GeForce RTX 3090, 24253MiB)
#                                                         CUDA:7 (NVIDIA GeForce RTX 3090, 24253MiB)
# Overriding model.yaml nc=80 with nc=1
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2376.4±745.4 MB/s, size: 73.4 KB)
# train: Scanning /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_binary_dataset/train/labels... 4227 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4227/4227 [00:03<00:00, 1233.15it/s]
# train: /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_binary_dataset/train/images/country2_001008.jpg: 1 duplicate labels removed
# train: /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_binary_dataset/train/images/country2_001950.jpg: 1 duplicate labels removed
# train: /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_binary_dataset/train/images/country2_002934.jpg: 1 duplicate labels removed
# train: /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_binary_dataset/train/images/country2_003494.jpg: 1 duplicate labels removed
# train: /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_binary_dataset/train/images/country2_005685.jpg: 1 duplicate labels removed
# train: /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_binary_dataset/train/images/country2_007271.jpg: 1 duplicate labels removed
# train: /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_binary_dataset/train/images/country2_008673.jpg: 1 duplicate labels removed
# train: /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_binary_dataset/train/images/country2_009457.jpg: 1 duplicate labels removed
# train: /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_binary_dataset/train/images/country2_012446.jpg: 1 duplicate labels removed
# train: /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_binary_dataset/train/images/country3_002943.jpg: 1 duplicate labels removed
# train: New cache created: /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_binary_dataset/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1589.1±1055.9 MB/s, size: 88.2 KB)
# val: Scanning /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_binary_dataset/val/labels... 906 images, 0 backgrounds, 0 corrupt: 100%|██████████| 906/906 [00:00<00:00, 1020.07it/s]
# val: /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_binary_dataset/val/images/country2_004318.jpg: 1 duplicate labels removed
# val: New cache created: /home/kwdahun/2025IMSC-Hackathon-CRACKPINK/yolo_binary_dataset/val/labels.cache
# Plotting labels to runs/detect/binary_road_damage_detection4/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.000875), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using
640: 100%|██████████| 38/38 [00:14<00:00,  2.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 29/29 [00:02<00:00, 10.57it/s]
#                    all        906       2453      0.574      0.499      0.517      0.233
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/150      4.04G      1.647      1.522      1.509         45        640: 100%|██████████| 38/38 [00:14<00:00,  2.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 29/29 [00:02<00:00, 10.55it/s]
#                    all        906       2453      0.555      0.511      0.511      0.226
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/150      4.05G      1.635      1.487      1.488         66        640: 100%|██████████| 38/38 [00:14<00:00,  2.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 29/29 [00:02<00:00, 10.61it/s]
#                    all        906       2453      0.565      0.492      0.506       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/150      4.06G      1.655      1.502      1.502         53        640: 100%|██████████| 38/38 [00:14<00:00,  2.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 29/29 [00:02<00:00, 10.48it/s]
#                    all        906       2453      0.559      0.506      0.509      0.224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/150      4.08G      1.666      1.479      1.507         43        640: 100%|██████████| 38/38 [00:14<00:00,  2.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 29/29 [00:02<00:00, 10.49it/s]
#                    all        906       2453      0.585      0.496      0.506      0.224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/150       4.1G      1.646      1.492      1.493         31        640: 100%|██████████| 38/38 [00:14<00:00,  2.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 29/29 [00:02<00:00, 10.57it/s]
#                    all        906       2453      0.541      0.504      0.488       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/150      4.11G       1.63      1.477      1.485         32        640: 100%|██████████| 38/38 [00:14<00:00,  2.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 29/29 [00:02<00:00, 10.53it/s]
# ...
# [rank2]:     return func(*args, **kwargs)
# [rank2]:            ^^^^^^^^^^^^^^^^^^^^^
# [rank2]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/distributed_c10d.py", line 2730, in broadcast
# [rank2]:     work.wait()
# [rank2]: torch.distributed.DistBackendError: [Rank 2] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=22995, OpType=BROADCAST, NumelIn=1, NumelOut=1, Timeout(ms)=10800000) ran for 10800000 milliseconds before timing out.
#
# [rank2]: During handling of the above exception, another exception occurred:
#
# [rank2]: Traceback (most recent call last):
# [rank2]:   File "/home/kwdahun/.config/Ultralytics/DDP/_temp_idgvoxra125327285350912.py", line 13, in <module>
# [rank2]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 227, in train
# [rank2]:     self._do_train(world_size)
# [rank2]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 487, in _do_train
# [rank2]:     dist.broadcast_object_list(broadcast_list, 0)  # broadcast 'stop' to all ranks
# [rank2]:     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank2]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 81, in wrapper
# [rank2]:     return func(*args, **kwargs)
# [rank2]:            ^^^^^^^^^^^^^^^^^^^^^
# [rank2]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/distributed_c10d.py", line 3479, in broadcast_object_list
# [rank2]:     broadcast(object_sizes_tensor, src=global_src, group=group)
# [rank2]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 83, in wrapper
# [rank2]:     msg_dict = _get_msg_dict(func.__name__, *args, **kwargs)
# [rank2]:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank2]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 51, in _get_msg_dict
# [rank2]:     def _get_msg_dict(func_name, *args, **kwargs) -> Dict[str, Any]:
# [rank2]:
# [rank2]: KeyboardInterrupt
# [rank4]: Traceback (most recent call last):
# [rank4]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 81, in wrapper
# [rank4]:     return func(*args, **kwargs)
# [rank4]:            ^^^^^^^^^^^^^^^^^^^^^
# [rank4]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/distributed_c10d.py", line 2730, in broadcast
# [rank4]:     work.wait()
# [rank4]: torch.distributed.DistBackendError: [Rank 4] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=22995, OpType=BROADCAST, NumelIn=1, NumelOut=1, Timeout(ms)=10800000) ran for 10800000 milliseconds before timing out.
#
# [rank4]: During handling of the above exception, another exception occurred:
#
# [rank4]: Traceback (most recent call last):
# [rank4]:   File "/home/kwdahun/.config/Ultralytics/DDP/_temp_idgvoxra125327285350912.py", line 13, in <module>
# [rank4]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 227, in train
# [rank4]:     self._do_train(world_size)
# [rank4]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 487, in _do_train
# [rank4]:     dist.broadcast_object_list(broadcast_list, 0)  # broadcast 'stop' to all ranks
# [rank4]:     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank4]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 81, in wrapper
# [rank4]:     return func(*args, **kwargs)
# [rank4]:            ^^^^^^^^^^^^^^^^^^^^^
# [rank4]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/distributed_c10d.py", line 3479, in broadcast_object_list
# [rank4]:     broadcast(object_sizes_tensor, src=global_src, group=group)
# [rank4]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 83, in wrapper
# [rank4]:     msg_dict = _get_msg_dict(func.__name__, *args, **kwargs)
# [rank4]:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank4]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 51, in _get_msg_dict
# [rank4]:     def _get_msg_dict(func_name, *args, **kwargs) -> Dict[str, Any]:
# [rank4]:
# [rank4]: KeyboardInterrupt
# [rank5]:[E725 06:20:13.533844813 ProcessGroupNCCL.cpp:681] [Rank 5] Some NCCL operations have failed or timed out. Due to the asynchronous nature of CUDA kernels, subsequent GPU operations might run on corrupted/incomplete data.
# [rank5]:[E725 06:20:13.533883793 ProcessGroupNCCL.cpp:695] [Rank 5] To avoid data inconsistency, we are taking the entire process down.
# [rank5]: Traceback (most recent call last):
# [rank5]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 81, in wrapper
# [rank5]:     return func(*args, **kwargs)
# [rank5]:            ^^^^^^^^^^^^^^^^^^^^^
# [rank5]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/distributed_c10d.py", line 2730, in broadcast
# [rank5]:     work.wait()
# [rank5]: torch.distributed.DistBackendError: [Rank 5] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=22995, OpType=BROADCAST, NumelIn=1, NumelOut=1, Timeout(ms)=10800000) ran for 10800000 milliseconds before timing out.
#
# [rank5]: During handling of the above exception, another exception occurred:
#
# [rank5]: Traceback (most recent call last):
# [rank5]:   File "/home/kwdahun/.config/Ultralytics/DDP/_temp_idgvoxra125327285350912.py", line 13, in <module>
# [rank5]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 227, in train
# [rank5]:     self._do_train(world_size)
# [rank5]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 487, in _do_train
# [rank5]:     dist.broadcast_object_list(broadcast_list, 0)  # broadcast 'stop' to all ranks
# [rank5]:     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank5]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 81, in wrapper
# [rank5]:     return func(*args, **kwargs)
# [rank5]:            ^^^^^^^^^^^^^^^^^^^^^
# [rank5]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/distributed_c10d.py", line 3479, in broadcast_object_list
# [rank5]:     broadcast(object_sizes_tensor, src=global_src, group=group)
# [rank5]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 83, in wrapper
# [rank5]:     msg_dict = _get_msg_dict(func.__name__, *args, **kwargs)
# [rank5]:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank5]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 51, in _get_msg_dict
# [rank5]:     def _get_msg_dict(func_name, *args, **kwargs) -> Dict[str, Any]:
# [rank5]:
# [rank5]: KeyboardInterrupt
# [rank3]:[E725 06:20:13.665475935 ProcessGroupNCCL.cpp:681] [Rank 3] Some NCCL operations have failed or timed out. Due to the asynchronous nature of CUDA kernels, subsequent GPU operations might run on corrupted/incomplete data.
# [rank3]:[E725 06:20:13.665516094 ProcessGroupNCCL.cpp:695] [Rank 3] To avoid data inconsistency, we are taking the entire process down.
# [rank3]: Traceback (most recent call last):
# [rank3]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 81, in wrapper
# [rank3]:     return func(*args, **kwargs)
# [rank3]:            ^^^^^^^^^^^^^^^^^^^^^
# [rank3]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/distributed_c10d.py", line 2730, in broadcast
# [rank3]:     work.wait()
# [rank3]: torch.distributed.DistBackendError: [Rank 3] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=22995, OpType=BROADCAST, NumelIn=1, NumelOut=1, Timeout(ms)=10800000) ran for 10800000 milliseconds before timing out.
#
# [rank3]: During handling of the above exception, another exception occurred:
#
# [rank3]: Traceback (most recent call last):
# [rank3]:   File "/home/kwdahun/.config/Ultralytics/DDP/_temp_idgvoxra125327285350912.py", line 13, in <module>
# [rank3]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 227, in train
# [rank3]:     self._do_train(world_size)
# [rank3]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 487, in _do_train
# [rank3]:     dist.broadcast_object_list(broadcast_list, 0)  # broadcast 'stop' to all ranks
# [rank3]:     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank3]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 81, in wrapper
# [rank3]:     return func(*args, **kwargs)
# [rank3]:            ^^^^^^^^^^^^^^^^^^^^^
# [rank3]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/distributed_c10d.py", line 3479, in broadcast_object_list
# [rank3]:     broadcast(object_sizes_tensor, src=global_src, group=group)
# [rank3]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 83, in wrapper
# [rank3]:     msg_dict = _get_msg_dict(func.__name__, *args, **kwargs)
# [rank3]:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank3]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 51, in _get_msg_dict
# [rank3]:     def _get_msg_dict(func_name, *args, **kwargs) -> Dict[str, Any]:
# [rank3]:
# [rank3]: KeyboardInterrupt
# [rank6]:[E725 06:20:13.807407699 ProcessGroupNCCL.cpp:681] [Rank 6] Some NCCL operations have failed or timed out. Due to the asynchronous nature of CUDA kernels, subsequent GPU operations might run on corrupted/incomplete data.
# [rank6]:[E725 06:20:13.807444869 ProcessGroupNCCL.cpp:695] [Rank 6] To avoid data inconsistency, we are taking the entire process down.
# [rank6]: Traceback (most recent call last):
# [rank6]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 81, in wrapper
# [rank6]:     return func(*args, **kwargs)
# [rank6]:            ^^^^^^^^^^^^^^^^^^^^^
# [rank6]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/distributed_c10d.py", line 2730, in broadcast
# [rank6]:     work.wait()
# [rank6]: torch.distributed.DistBackendError: [Rank 6] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=22995, OpType=BROADCAST, NumelIn=1, NumelOut=1, Timeout(ms)=10800000) ran for 10800000 milliseconds before timing out.
#
# [rank6]: During handling of the above exception, another exception occurred:
#
# [rank6]: Traceback (most recent call last):
# [rank6]:   File "/home/kwdahun/.config/Ultralytics/DDP/_temp_idgvoxra125327285350912.py", line 13, in <module>
# [rank6]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 227, in train
# [rank6]:     self._do_train(world_size)
# [rank6]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 487, in _do_train
# [rank6]:     dist.broadcast_object_list(broadcast_list, 0)  # broadcast 'stop' to all ranks
# [rank6]:     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank6]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 81, in wrapper
# [rank6]:     return func(*args, **kwargs)
# [rank6]:            ^^^^^^^^^^^^^^^^^^^^^
# [rank6]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/distributed_c10d.py", line 3479, in broadcast_object_list
# [rank6]:     broadcast(object_sizes_tensor, src=global_src, group=group)
# [rank6]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 83, in wrapper
# [rank6]:     msg_dict = _get_msg_dict(func.__name__, *args, **kwargs)
# [rank6]:                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [rank6]:   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 51, in _get_msg_dict
# [rank6]:     def _get_msg_dict(func_name, *args, **kwargs) -> Dict[str, Any]:
# [rank6]:
# [rank6]: KeyboardInterrupt
# [rank1]:[E725 06:20:13.110589232 ProcessGroupNCCL.cpp:681] [Rank 1] Some NCCL operations have failed or timed out. Due to the asynchronous nature of CUDA kernels, subsequent GPU operations might run on corrupted/incomplete data.
# [rank1]:[E725 06:20:13.110617152 ProcessGroupNCCL.cpp:695] [Rank 1] To avoid data inconsistency, we are taking the entire process down.
# Error in sys.excepthook:
# Traceback (most recent call last):
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/distributed_c10d.py", line 1742, in _distributed_excepthook
#     def _distributed_excepthook(*args):
#
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/utils/data/_utils/signal_handling.py", line 73, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 1371419) exited unexpectedly with exit code 1. Details are lost due to multiprocessing. Rerunning with num_workers=0 may give better error trace.
#
# Original exception was:
# Traceback (most recent call last):
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 81, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/distributed_c10d.py", line 2730, in broadcast
#     work.wait()
# torch.distributed.DistBackendError: [Rank 1] Watchdog caught collective operation timeout: WorkNCCL(SeqNum=22995, OpType=BROADCAST, NumelIn=1, NumelOut=1, Timeout(ms)=10800000) ran for 10800000 milliseconds before timing out.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/kwdahun/.config/Ultralytics/DDP/_temp_idgvoxra125327285350912.py", line 13, in <module>
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 227, in train
#     self._do_train(world_size)
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/ultralytics/engine/trainer.py", line 487, in _do_train
#     dist.broadcast_object_list(broadcast_list, 0)  # broadcast 'stop' to all ranks
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 81, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/distributed_c10d.py", line 3479, in broadcast_object_list
#     broadcast(object_sizes_tensor, src=global_src, group=group)
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 83, in wrapper
#     msg_dict = _get_msg_dict(func.__name__, *args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kwdahun/anaconda3/envs/yolo_env/lib/python3.12/site-packages/torch/distributed/c10d_logger.py", line 51, in _get_msg_dict
#     def _get_msg_dict(func_name, *args, **kwargs) -> Dict[str, Any]:
#
# KeyboardInterrupt

# %%
train_dirs = sorted(glob('runs/detect/binary_road_damage_detection*'), key=os.path.getmtime, reverse=True)
if train_dirs:
    best_model_path = f"{train_dirs[0]}/weights/best.pt"
    eval_model = YOLO(best_model_path)
else:
    eval_model = model

results = eval_model.val(data=f'{dataset_path}/data.yaml', split='test', device=0, verbose=False)

print(f"mAP@0.5: {results.box.map50:.4f}")
print(f"mAP@0.5:0.95: {results.box.map:.4f}")
print(f"Precision: {results.box.mp:.4f}")
print(f"Recall: {results.box.mr:.4f}")
print(f"F1-Score: {2 * (results.box.mp * results.box.mr) / (results.box.mp + results.box.mr):.4f}")

# %%
train_dirs = sorted(glob('runs/detect/binary_road_damage_detection*'), key=os.path.getmtime, reverse=True)
if train_dirs:
    best_model_path = f"{train_dirs[0]}/weights/best.pt"
    os.makedirs('binary_yolo_checkpoints', exist_ok=True)
    shutil.copy(best_model_path, 'binary_yolo_checkpoints/best_binary_road_damage.pt')
    print("Model saved: binary_yolo_checkpoints/best_binary_road_damage.pt")

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import cv2

def load_best_binary_model():
    if os.path.exists('binary_yolo_checkpoints/best_binary_road_damage.pt'):
        return YOLO('binary_yolo_checkpoints/best_binary_road_damage.pt')
    train_dirs = sorted(glob('runs/detect/binary_road_damage_detection*'), key=os.path.getmtime, reverse=True)
    if train_dirs:
        return YOLO(f"{train_dirs[0]}/weights/best.pt")
    return YOLO('yolov8m.pt')

def visualize_predictions(model, image_path, conf_threshold=0.5):
    results = model(image_path, device=0, conf=conf_threshold)
    annotated_img = results[0].plot()
    
    plt.figure(figsize=(12, 8))
    plt.imshow(cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB))
    plt.title(f"Detection: {Path(image_path).name}")
    plt.axis('off')
    
    boxes = results[0].boxes
    if boxes is not None and len(boxes) > 0:
        print(f"Detections: {len(boxes)}, Max confidence: {boxes.conf.max():.3f}")
    else:
        print("No detections")
    return results

# Run inference
trained_model = load_best_binary_model()
test_images = glob(f'{dataset_path}/test/images/*.jpg')[:3]

for img_path in test_images:
    visualize_predictions(trained_model, img_path, conf_threshold=0.3)
    plt.show()

# %%
if os.path.exists('binary_yolo_checkpoints/best_binary_road_damage.pt'):
    final_model = YOLO('binary_yolo_checkpoints/best_binary_road_damage.pt')
    
    total_train = len(glob(f'{dataset_path}/train/images/*.jpg') + glob(f'{dataset_path}/train/images/*.png'))
    total_val = len(glob(f'{dataset_path}/val/images/*.jpg') + glob(f'{dataset_path}/val/images/*.png'))
    total_test = len(glob(f'{dataset_path}/test/images/*.jpg') + glob(f'{dataset_path}/test/images/*.png'))
    
    print(f"Model: YOLOv8m Binary Classification")
    print(f"Dataset: {dataset_path}")
    print(f"Images - Train: {total_train}, Val: {total_val}, Test: {total_test}")
    print(f"Total: {total_train + total_val + total_test}")
else:
    print("Model not found")
